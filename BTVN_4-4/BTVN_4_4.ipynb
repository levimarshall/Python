# %%
diem15p = float(input('Nhập vào điểm 15p: '))
diemgk = float(input('Nhập vào điểm giữa kỳ: '))
diemck = float(input('Nhập vào điểm cuối kỳ: '))
if diem15p < 0 or diem15p >10 or diemgk < 0 or diemgk >10 or diemck < 0 or diemck >10:
    print('Sai điểm')
else:
    diemtb = (diem15p*1 + diemgk*1.5 + diemck*2)/4.5
    if diemtb >= 8:
        hocluc = 'Giỏi'
    elif diemtb >= 6.5:
        hocluc = 'Khá'
    elif diemtb >= 5:
        hocluc = 'Trung bình'
    else: 
        hocluc = 'Yếu'
    print(hocluc)
# Out:
# Nhập vào điểm 15p: 2
# Nhập vào điểm giữa kỳ: 3
# Nhập vào điểm cuối kỳ: 4
# Yếu

# %%
a = int(input('Nhập hệ số a: '))
b = int(input('Nhập hệ số b: '))
c = int(input('Nhập hệ số c: '))

# ax^2 + bx + c
# ax^2 - bx + c
# ax^2 + bx - c
# ax^2 - bx - c

# ax^2 + c
# ax^2 - c

# ax^2 + bx
# ax^2 - bx

# ax^2


if a == 0:
    print('Không phải phương trình bậc 2.')
elif a == 1:
    if b == 1 and c == 1:
        print('x^2 + x + 1')
    elif b == 1 and c == -1:
        print('x^2 + x - 1')
    elif b == -1 and c == 1:
        print('x^2 - x + 1')
    elif b == -1 and c == -1:
        print('x^2 - x - 1')
    elif b == 0 and c == 1:
        print('x^2 + 1')
    elif b == 0 and c == -1:
        print('x^2 - 1')
    elif b == 1 and c == 0:
        print('x^2 + x')
    elif b == -1 and c == 0:
        print('x^2 - x')
    elif b == 1 and c > 0:
        print('x^2 + x + {0}'.format(c))
    elif b == 1 and c < 0:
        c = 0 - c
        print('x^2 + x - {0}'.format(c))
    elif b < 0 and c > 0:
        b = 0 - b
        print('x^2 - {0}x + {1}'.format(b,c))
    elif b > 0 and c < 0:
        c = 0 - c
        print('x^2 + {0}x - {1}'.format(b,c))
    elif b < 0 and c < 0:
        b = 0 - b
        c = 0 - c
        print('x^2 - {0}x - {1}'.format(b,c))
    elif b == 0 and c > 0:
        print('x^2 + {0}'.format(c))
    elif b == 0 and c < 0:
        c = 0 - c
        print('x^2 - {0}'.format(c))  
    elif b > 0 and c == 0:
        print('x^2 + {0}x'.format(b))
    elif b < 0 and c == 0:
        b == 0 - b
        print('x^2 - {0}x'.format(b))
    elif b == 0 and c == 0:
        print('x^2')
    else:
        print('x^2 + {0}x + {1}'.format(b,c))
elif a == -1:
    if b == 1 and c == 1:
        print('-x^2 + x + 1')
    elif b == 1 and c == -1:
        print('-x^2 + x - 1')
    elif b == -1 and c == 1:
        print('-x^2 - x + 1')
    elif b == -1 and c == -1:
        print('-x^2 - x - 1')
    elif b == 0 and c == 1:
        print('-x^2 + 1')
    elif b == 0 and c == -1:
        print('-x^2 - 1')
    elif b == 1 and c == 0:
        print('-x^2 + x')
    elif b == -1 and c == 0:
        print('-x^2 - x')
    elif b == 1 and c > 0:
        print('-x^2 + x + {0}'.format(c))
    elif b == 1 and c < 0:
        c = 0 - c
        print('-x^2 + x - {0}'.format(c))
    elif b < 0 and c > 0:
        b = 0 - b
        print('-x^2 - {0}x + {1}'.format(b,c))
    elif b > 0 and c < 0:
        c = 0 - c
        print('-x^2 + {0}x - {1}'.format(b,c))
    elif b < 0 and c < 0:
        b = 0 - b
        c = 0 - c
        print('-x^2 - {0}x - {1}'.format(b,c))
    elif b == 0 and c > 0:
        print('-x^2 + {0}'.format(c))
    elif b == 0 and c < 0:
        c = 0 - c
        print('-x^2 - {0}'.format(c))  
    elif b > 0 and c == 0:
        print('-x^2 + {0}x'.format(b))
    elif b < 0 and c == 0:
        b == 0 - b
        print('-x^2 - {0}x'.format(b))
    elif b == 0 and c == 0:
        print('-x^2')
    else:
        print('-x^2 + {0}x + {1}'.format(b,c))
else:
    if b == 1 and c == 1:
        print('{0}x^2 + x + 1'.format(a))
    elif b == 1 and c == -1:
        print('{0}x^2 + x - 1'.format(a))
    elif b == -1 and c == 1:
        print('{0}x^2 - x + 1'.format(a))
    elif b == -1 and c == -1:
        print('{0}x^2 - x - 1'.format(a))
    elif b == 0 and c == 1:
        print('{0}x^2 + 1'.format(a))
    elif b == 0 and c == -1:
        print('{0}x^2 - 1'.format(a))
    elif b == 1 and c == 0:
        print('{0}x^2 + x'.format(a))
    elif b == -1 and c == 0:
        print('{0}x^2 - x'.format(a))
    elif b == 1 and c > 0:
        print('{0}x^2 + x + {1}'.format(a,c))
    elif b == 1 and c < 0:
        c = 0 - c
        print('{0}x^2 + x - {1}'.format(a,c))
    elif b < 0 and c > 0:
        b = 0 - b
        print('{0}x^2 - {1}x + {2}'.format(a,b,c))
    elif b > 0 and c < 0:
        c = 0 - c
        print('{0}x^2 + {1}x - {2}'.format(a,b,c))
    elif b < 0 and c < 0:
        b = 0 - b
        c = 0 - c
        print('{0}x^2 - {1}x - {2}'.format(a,b,c))
    elif b == 0 and c > 0:
        print('{0}x^2 + {1}'.format(a,c))
    elif b == 0 and c < 0:
        c = 0 - c
        print('{0}x^2 - {1}'.format(a,c))  
    elif b > 0 and c == 0:
        print('{0}x^2 + {1}x'.format(a,b))
    elif b < 0 and c == 0:
        b = 0 - b
        print('{0}x^2 - {1}x'.format(a,b))
    elif b == 0 and c == 0:
        print('{0}x^2'.format(a))
    else:
        print('{0}x^2 + {1}x + {2}'.format(a,b,c))
# Out:
# Nhập hệ số a: 8
# Nhập hệ số b: -1
# Nhập hệ số c: -9
# 8x^2 - 1x - 9

# %% [markdown]
# #
