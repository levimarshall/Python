# %%
import turtle

rua1 = turtle.Turtle()
rua2 = turtle.Turtle()
rua3 = turtle.Turtle()
rua4 = turtle.Turtle()
rua5 = turtle.Turtle()
rua6 = turtle.Turtle()
rua8 = turtle.Turtle()
rua9 = turtle.Turtle()
rua11 = turtle.Turtle()
rua12 = turtle.Turtle()
rua13 = turtle.Turtle()
rua14 = turtle.Turtle()

rua1.ht()
rua2.ht()
rua3.ht()
rua4.ht()
rua5.ht()
rua6.ht()
rua8.ht()
rua9.ht()
rua11.ht()
rua12.ht()
rua13.ht()
rua14.ht()


rua1.speed(0)
rua2.speed(0)
rua3.speed(0)
rua4.speed(0)
rua5.speed(0)
rua6.speed(0)
rua8.speed(0)
rua9.speed(0)
rua11.speed(0)
rua12.speed(0)
rua13.speed(0)
rua14.speed(0)

# than nguoi tuyet
rua1.pensize(2)
rua1.fillcolor('#F2F9FA')
rua1.begin_fill()
rua1.penup()
rua1. right(90)
rua1.forward(400)
rua1.left(90)
rua1.pendown()
rua1.circle(200)
rua1.end_fill()

# cuc ao
rua3.penup()
rua3. right(90)
rua3.forward(125)
rua3.left(90)
rua3.pendown()
rua3.dot(30)

rua4.penup()
rua4. right(90)
rua4.forward(200)
rua4.left(90)
rua4.pendown()
rua4.dot(30)

rua5.penup()
rua5. right(90)
rua5.forward(275)
rua5.left(90)
rua5.pendown()
rua5.dot(30)

# tay phải
rua6.pensize(2)

rua6.penup()
rua6.left(90)
rua6.fd(70)
rua6.left(90)
rua6.fd(200)
rua6.pendown()
rua6.left(100)
rua6.circle(163, 50, 10)
rua6.penup()
rua6.setpos(-250, 45)
rua6.pendown()
rua6.left(-60)
rua6.circle(270, 40, 10)


# găng tay 
rua8.pensize(2)
rua8.penup()
rua8.left(90)
rua8.fd(70)
rua8.left(90)
rua8.fd(200)
rua8.pendown()
rua8.fillcolor('#8F2F0B')
rua8.begin_fill()
rua8.left(25)
rua8.fd(65)
rua8.backward(75)
rua8.right(90)
rua8.fd(10)
rua8.right(90)
rua8.circle(10, 200, 100)
rua8.left(220)
rua8.circle(39, 220, 100)
rua8.right(10)
rua8.fd(43)
rua8.end_fill()

# tay trái
rua9.pensize(2)

rua9.penup()
rua9.setpos(124,-45)

rua9.pendown()
rua9.right(10)
rua9.fd(100)
rua9.right(130)
rua9.circle(30)
rua9.penup()
rua9.setpos(182.5, -118)
rua9.pendown()
rua9.right(213)
rua9.fd(47)


# khăn

rua11.fillcolor('#7A2104')
rua11.begin_fill()
rua11.penup()
rua11.left(90)
rua11.fd(20)
rua11.left(90)
rua11.fd(102)
rua11.pendown()
rua11.left(80)
rua11.circle(250, 12, 100)
rua11.left(50)
rua11.circle(180, 60, 100)
rua11.right(120)
rua11.bk(60)
rua11.fd(140)

rua11.left(100)
rua11.fd(75)
rua11.left(100)
rua11.fd(160)
rua11.penup()
rua11.right(52)
rua11.circle(135, 260, 100)
rua11.pendown()
rua11.circle(135, 100, 100)
rua11.end_fill()

# đầu
rua2.pensize(2)
rua2.fillcolor('#F2F9FA')
rua2.begin_fill()
rua2.penup()
rua2.right(90)
rua2.forward(25)
rua2.left(90)
rua2.pendown()
rua2.circle(135)
rua2.end_fill()

# mũi
rua12.fillcolor('#F8C45E')
rua12.setpos(5,100)
rua12.begin_fill()
rua12.left(10)
rua12.fd(30)
rua12.left(80)
rua12.fd(10)
rua12.bk(10)
rua12.right(80)
rua12.fd(50)
rua12.left(80)
rua12.fd(7)
rua12.bk(7)
rua12.right(80)
rua12.fd(60)
rua12.left(165)
rua12.fd(80)
rua12.left(95)
rua12.fd(7)
rua12.bk(7)
rua12.right(95)
rua12.fd(40)
rua12.left(95)
rua12.fd(17)
rua12.bk(17)
rua12.right(95)
rua12.fd(20)
rua12.left(95)
rua12.fd(40)
rua12.end_fill()

# mắt + miệng
rua13.pensize(3)
rua13.penup()
rua13.setpos(30, 170)
rua13.pendown()
rua13.dot(20)
rua13.penup()
rua13.setpos(-25, 170)
rua13.pendown()
rua13.dot(22)
rua13.penup()
rua13.setpos(-90, 120)
rua13.left(40)
rua13.fd(30)
rua13.pendown()
rua13.left(150)
rua13.circle(180, 10, 100)
rua13.penup()
rua13.setpos(-85, 133)
rua13.pendown()
rua13.left(70)
rua13.circle(100, 120, 100)

# mũ
rua14.fillcolor('#A76740')
rua14.penup()
rua14.setpos(40, 260)
rua14.pendown()
rua14.pensize(20)
rua14.pencolor('#A76740')
rua14.left(18)
rua14.bk(170)
rua14.fd(35)
rua14.pensize(3)
rua14.left(100)
rua14.begin_fill()
rua14.fd(120)
rua14.bk(120)
rua14.right(100)
rua14.fd(100)
rua14.left(80)
rua14.fd(120)
rua14.left(94)
rua14.circle(700, 11.7, 100)
rua14.end_fill()










turtle.done()
